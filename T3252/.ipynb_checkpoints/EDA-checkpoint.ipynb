# %%
pwd
# Out:
# '/opt/ml/code/MyCode'

# %%
from sklearn.model_selection import train_test_split as tts
import pandas as pd
import matplotlib.pyplot as plt
df = pd.read_csv('/opt/ml/dataset/train/train.csv')
df.head()
# Out:
#    id                                           sentence  \
# 0   0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1   1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 2   2  K리그2에서 성적 1위를 달리고 있는 광주FC는 지난 26일 한국프로축구연맹으로부터...
# 3   3  균일가 생활용품점 (주)아성다이소(대표 박정부)는 코로나19 바이러스로 어려움을 겪...
# 4   4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
#
#                                       subject_entity  \
# 0  {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1  {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 2  {'word': '광주FC', 'start_idx': 21, 'end_idx': 2...
# 3  {'word': '아성다이소', 'start_idx': 13, 'end_idx': ...
# 4  {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
#
#                                        object_entity  \
# 0  {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...
# 1  {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...
# 2  {'word': '한국프로축구연맹', 'start_idx': 34, 'end_idx...
# 3  {'word': '박정부', 'start_idx': 22, 'end_idx': 24...
# 4  {'word': '1967', 'start_idx': 0, 'end_idx': 3,...
#
#                        label     source
# 0                no_relation  wikipedia
# 1                no_relation   wikitree
# 2              org:member_of   wikitree
# 3  org:top_members/employees   wikitree
# 4                no_relation  wikipedia

# %%
df[df.label == 'org:founded'].head() # 설립년도
df[df.label == 'per:product'].head() # 만든 작품, 춤 ..
df[df.label == 'org:political/religious_affiliation'].head() # 나라, 제도가 존재하는 곳 , 종교
df[df.label == 'org:dissolved'].head() # 나라, 기관 : 더이상 이어지지 않는 년도
df[df.label == 'per:origin'].head() # 국가가 아니더라도 단체소속도 포함
#ind 125번 뒤바뀜 소녀시대, 제시카 
df[df.label == 'no_relation'].head()
# Out:
#     id                                           sentence  \
# 0    0  〈Something〉는 조지 해리슨이 쓰고 비틀즈가 1969년 앨범 《Abbey R...
# 1    1  호남이 기반인 바른미래당·대안신당·민주평화당이 우여곡절 끝에 합당해 민생당(가칭)으...
# 4    4  1967년 프로 야구 드래프트 1순위로 요미우리 자이언츠에게 입단하면서 등번호는 8...
# 6    6  그에 따라 나폴리와 계약을 연장한 마라도나는 1989년 팀을 UEFA컵 정상으로 인...
# 14  14  조토 디 본도네, 마사초, 피에로 델라 프란체스카, 도메니코 기를란다요, 페루지노,...
#
#                                        subject_entity  \
# 0   {'word': '비틀즈', 'start_idx': 24, 'end_idx': 26...
# 1   {'word': '민주평화당', 'start_idx': 19, 'end_idx': ...
# 4   {'word': '요미우리 자이언츠', 'start_idx': 22, 'end_id...
# 6   {'word': 'AC 밀란', 'start_idx': 64, 'end_idx': ...
# 14  {'word': '미켈란젤로', 'start_idx': 47, 'end_idx': ...
#
#                                         object_entity        label     source
# 0   {'word': '조지 해리슨', 'start_idx': 13, 'end_idx':...  no_relation  wikipedia
# 1   {'word': '대안신당', 'start_idx': 14, 'end_idx': 1...  no_relation   wikitree
# 4   {'word': '1967', 'start_idx': 0, 'end_idx': 3,...  no_relation  wikipedia
# 6   {'word': '1989', 'start_idx': 25, 'end_idx': 2...  no_relation  wikipedia
# 14  {'word': '르네상스', 'start_idx': 96, 'end_idx': 9...  no_relation  wikipedia

# %%
df.label.value_counts().to_frame().style.background_gradient()
# Out:
# <style  type="text/css" >
# #T_c3659466_ab15_11ec_9255_0242ac110002row0_col0{
#             background-color:  #023858;
#             color:  #f1f1f1;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row1_col0{
#             background-color:  #89b1d4;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row2_col0{
#             background-color:  #a7bddb;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row3_col0{
#             background-color:  #d8d7e9;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row4_col0{
#             background-color:  #dddbec;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row5_col0{
#             background-color:  #eae6f1;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row6_col0{
#             background-color:  #ece7f2;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row7_col0{
#             background-color:  #ede7f2;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row8_col0{
#             background-color:  #eee8f3;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row9_col0{
#             background-color:  #f0eaf4;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row10_col0{
#             background-color:  #f3edf5;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row11_col0{
#             background-color:  #f7f0f7;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row12_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row13_col0{
#             background-color:  #f8f1f8;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row14_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row15_col0{
#             background-color:  #f9f2f8;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row16_col0{
#             background-color:  #faf2f8;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row17_col0{
#             background-color:  #fbf3f9;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row18_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row19_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row20_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row21_col0{
#             background-color:  #fdf5fa;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row22_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row23_col0{
#             background-color:  #fef6fa;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row24_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row25_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row26_col0{
#             background-color:  #fef6fb;
#             color:  #000000;
#         }#T_c3659466_ab15_11ec_9255_0242ac110002row27_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row28_col0,#T_c3659466_ab15_11ec_9255_0242ac110002row29_col0{
#             background-color:  #fff7fb;
#             color:  #000000;
#         }</style><table id="T_c3659466_ab15_11ec_9255_0242ac110002" ><thead>    <tr>        <th class="blank level0" ></th>        <th class="col_heading level0 col0" >label</th>    </tr></thead><tbody>
#                 <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row0" class="row_heading level0 row0" >no_relation</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row0_col0" class="data row0 col0" >9534</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row1" class="row_heading level0 row1" >org:top_members/employees</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row1_col0" class="data row1 col0" >4284</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row2" class="row_heading level0 row2" >per:employee_of</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row2_col0" class="data row2 col0" >3573</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row3" class="row_heading level0 row3" >per:title</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row3_col0" class="data row3 col0" >2103</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row4" class="row_heading level0 row4" >org:member_of</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row4_col0" class="data row4 col0" >1866</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row5" class="row_heading level0 row5" >org:alternate_names</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row5_col0" class="data row5 col0" >1320</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row6" class="row_heading level0 row6" >per:origin</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row6_col0" class="data row6 col0" >1234</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row7" class="row_heading level0 row7" >org:place_of_headquarters</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row7_col0" class="data row7 col0" >1195</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row8" class="row_heading level0 row8" >per:date_of_birth</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row8_col0" class="data row8 col0" >1130</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row9" class="row_heading level0 row9" >per:alternate_names</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row9_col0" class="data row9 col0" >1001</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row10" class="row_heading level0 row10" >per:spouse</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row10_col0" class="data row10 col0" >795</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row11" class="row_heading level0 row11" >per:colleagues</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row11_col0" class="data row11 col0" >534</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row12" class="row_heading level0 row12" >per:parents</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row12_col0" class="data row12 col0" >520</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row13" class="row_heading level0 row13" >org:founded</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row13_col0" class="data row13 col0" >450</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row14" class="row_heading level0 row14" >org:members</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row14_col0" class="data row14 col0" >420</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row15" class="row_heading level0 row15" >per:date_of_death</th>
#                         <td id="T_c3659466_ab15_11ec_9255_0242ac110002row15_col0" class="data row15 col0" >418</td>
#             </tr>
#             <tr>
#                         <th id="T_c3659466_ab15_11ec_9255_0242ac110002level0_row16

# %%
{0: 'no_relation', 1: 'org:top_members/employees', 2: 'org:members', 3: 'org:product', 4: 'per:title', 5: 'org:alternate_names', 6: 'per:employee_of', 7: 'org:place_of_headquarters', 8: 'per:product', 9: 'org:number_of_employees/members', 10: 'per:children', 11: 'per:place_of_residence', 12: 'per:alternate_names', 13: 'per:other_family', 14: 'per:colleagues', 15: 'per:origin', 16: 'per:siblings', 17: 'per:spouse', 18: 'org:founded', 19: 'org:political/religious_affiliation', 20: 'org:member_of', 21: 'per:parents', 22: 'org:dissolved', 23: 'per:schools_attended', 24: 'per:date_of_death', 25: 'per:date_of_birth', 26: 'per:place_of_birth', 27: 'per:place_of_death', 28: 'org:founded_by', 29: 'per:religion'}

# %% [markdown]
# # 순서 변경 가능 후보
# 1. 21 parents / 10 children  , 2 members / 20 member_0f
# 2. org:top_members/employees , per:employee_of
# 3. per:schools_attended , org:members
# 4. alternate_names reversed
